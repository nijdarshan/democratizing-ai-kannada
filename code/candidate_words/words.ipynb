# %%
# Open the file in read mode
with open('candidate_words copy.txt', 'r', encoding='utf-8') as file:
    # Read all lines from the file
    lines = file.readlines()

# Strip newline characters and convert to a list of strings
words_list = [line.strip() for line in lines]

# Print the list of words
print(words_list)
# Out:
# ['ಗುಂಟೆ', 'ಯಜಮಾನ', 'ಭಾವ', 'ಉದಯ', 'ಕಾಳು', 'ಪಟ್ಟಿ', 'ಮುತ್ತು', 'ಅನಾಮಿಕ', 'ಸಂಗತಿ', 'ಕಣ', 'ದಿವಾಳಿ', 'ಸುಪಾರಿ', 'ಧರಣಿ', 'ಹಸಿ', 'ತುರಿ', 'ವರುಷ', 'ಯಂತ್ರ', 'ಮಂಜು', 'ತೀರ್ಥ', 'ವರ', 'ಗ್ರಹ', 'ಗುಂಡು', 'ಪದ', 'ಅಡಿ', 'ಆಟ', 'ಎಲೆ', 'ಬನ್ನಿ', 'ಹೊತ್ತು', 'ಅಶೋಕ', 'ಸಂಧಿ', 'ಕ್ರಮ', 'ಮಟ್ಟ', 'ವಿಧಿ', 'ಬಗೆ', 'ಎಳೆ', 'ಅಕ್ಷರ', 'ಪೂರ್ವ', 'ಬಸವ', 'ಕಳೆ', 'ಬಂಡವಾಳ', 'ಕೈಲಾಸ', 'ಅಚ್ಚು', 'ರನ್ನ', 'ಕೇಸರಿ', 'ಸಿದ್ಧ', 'ನಿರ್ಮಾಪಕ', 'ಬಯಲು', 'ಮದ್ದು', 'ಭಾಗ್ಯ', 'ವರ್ಷ', 'ಸರ್ವಜ್ಞ', 'ನೆರೆ', 'ದಂತ', 'ಕೋಶ', 'ದಳ', 'ಬರೆ', 'ಅದಿರು', 'ಅಡ್ಡ', 'ಸೀಮೆ', 'ಸರಿ', 'ಭೂತ', 'ಶಿರಾ', 'ಕಸರತ್ತು', 'ಪಕ್ಷ', 'ಧ್ರುವ', 'ಕರ್ಮ', 'ಹೊಳೆ', 'ಗಜ', 'ಮಾರಿ', 'ಮಂಡಿ', 'ಮತ', 'ಪ್ರತಿ', 'ಲಿಂಗ', 'ನಾಮ', 'ರಂಗ', 'ತುಪ್ಪ', 'ರಾಶಿ', 'ವರ್ಣ', 'ಹುಟ್ಟು', 'ನೇರ', 'ಬದಿ', 'ದಂಡ', 'ಗಣಕ', 'ತಿಳಿ', 'ಮರಿ', 'ಪಕ್ಕ', 'ನರ', 'ಎಡೆ', 'ಹರಿ', 'ಕಿರುಕುಳ', 'ಸ್ಥಾನ', 'ಬಿಲ್ಲು', 'ಗುರು', 'ಉತ್ತರ', 'ಮೃಗ', 'ಸೋಮ', 'ಸೇರು', 'ಗಂಡ', 'ಗುಂಡಿ', 'ಬೆಳೆ', 'ತೆರೆ', 'ಕಡಿತ', 'ವರ್ಗ', 'ಚರಣ', 'ಕರೆ', 'ಕಲೆ', 'ಕರ', 'ಸಾರ', 'ಬಿಂದು', 'ಬೊಗಳೆ', 'ಕೂಲಿ', 'ಈಶಾನ್ಯ', 'ದತ್ತಿ', 'ಹೃದಯ', 'ರತಿ', 'ಸಿಡಿ', 'ಹಿರಿಯ', 'ಭಟ್ಟ', 'ಗುಡುಗು', 'ಅಂಗ', 'ಕಂಬಳ', 'ಕೊಂಡ', 'ಕಾಡು', 'ಕಲ್ಯಾಣ', 'ಕೂಟ', 'ಕಲಿ', 'ಸರಕು', 'ಗಂಡ', 'ನಂದಿ', 'ನುಡಿ', 'ಕಾಯಿ', 'ನೆಲೆ', 'ಅಲೆ', 'ತೆರೆ', 'ಕರ್ಣ']

# %%
len(words_list)
# Out:
# 135
