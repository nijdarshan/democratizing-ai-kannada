# %%
import pandas as pd

# %%
df = pd.read_csv('kannada_polysemy_sentences.csv')

# %%
words = df[df.word.unique()]
# Out:
# 133

# %%
df[df.word in df.word.unique()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[df.word in df.word.unique()]
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2168, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2164 @final
#    2165 def __array_ufunc__(
#    2166     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2167 ):
# -> 2168     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:276, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     273 kwargs = _standardize_out_kwarg(**kwargs)
#     275 # for binary ops, use our custom dunder methods
# --> 276 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
# ...

# %%
df.word.unique().tolist()
# Out:
# ['ಗುಂಟೆ',
#  'ಯಜಮಾನ',
#  'ಭಾವ',
#  'ಉದಯ',
#  'ಕಾಳು',
#  'ಪಟ್ಟಿ',
#  'ಮುತ್ತು',
#  'ಅನಾಮಿಕ',
#  'ಸಂಗತಿ',
#  'ಕಣ',
#  'ದಿವಾಳಿ',
#  'ಸುಪಾರಿ',
#  'ಧರಣಿ',
#  'ಹಸಿ',
#  'ತುರಿ',
#  'ವರುಷ',
#  'ಯಂತ್ರ',
#  'ಮಂಜು',
#  'ತೀರ್ಥ',
#  'ವರ',
#  'ಗ್ರಹ',
#  'ಗುಂಡು',
#  'ಪದ',
#  'ಅಡಿ',
#  'ಆಟ',
#  'ಎಲೆ',
#  'ಬನ್ನಿ',
#  'ಹೊತ್ತು',
#  'ಅಶೋಕ',
#  'ಸಂಧಿ',
#  'ಕ್ರಮ',
#  'ಮಟ್ಟ',
#  'ವಿಧಿ',
#  'ಬಗೆ',
#  'ಎಳೆ',
#  'ಅಕ್ಷರ',
#  'ಪೂರ್ವ',
#  'ಬಸವ',
#  'ಕಳೆ',
#  'ಬಂಡವಾಳ',
#  'ಕೈಲಾಸ',
#  'ಅಚ್ಚು',
#  'ರನ್ನ',
#  'ಕೇಸರಿ',
#  'ಸಿದ್ಧ',
#  'ನಿರ್ಮಾಪಕ',
#  'ಬಯಲು',
#  'ಮದ್ದು',
#  'ಭಾಗ್ಯ',
#  'ವರ್ಷ',
#  'ಸರ್ವಜ್ಞ',
#  'ನೆರೆ',
#  'ದಂತ',
#  'ಕೋಶ',
#  'ದಳ',
#  'ಬರೆ',
#  'ಅದಿರು',
#  'ಅಡ್ಡ',
#  'ಸೀಮೆ',
#  'ಸರಿ',
#  'ಭೂತ',
#  'ಶಿರಾ',
#  'ಕಸರತ್ತು',
#  'ಪಕ್ಷ',
#  'ಧ್ರುವ',
#  'ಕರ್ಮ',
#  'ಹೊಳೆ',
#  'ಗಜ',
#  'ಮಾರಿ',
#  'ಮಂಡಿ',
#  'ಮತ',
#  'ಪ್ರತಿ',
#  'ಲಿಂಗ',
#  'ನಾಮ',
#  'ರಂಗ',
#  'ತುಪ್ಪ',
#  'ರಾಶಿ',
#  'ವರ್ಣ',
#  'ಹುಟ್ಟು',
#  'ನೇರ',
#  'ಬದಿ',
#  'ದಂಡ',
#  'ಗಣಕ',
#  'ತಿಳಿ',
#  'ಮರಿ',
#  'ಪಕ್ಕ',
#  'ನರ',
#  'ಎಡೆ',
#  'ಹರಿ',
#  'ಕಿರುಕುಳ',
# ...
