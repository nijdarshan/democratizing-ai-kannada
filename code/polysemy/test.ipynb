# %%
import pandas as pd

# %%
df = pd.read_csv('polysemy.csv')
print(df['meaning_number'].value_counts())
# Out:
# meaning_number
# 2     10477
# 1     10476
# 3      5700
# 4      3305
# 5      1986
# 6      1253
# 7       786
# 8       529
# 9       361
# 10      263
# 12      174
# 14      118
# 16       83
# 18       61
# 20       47
# 22       37
# 24       27
# 11       20
# 26       18
# 28       17
# 13       14
# 29       13
# 31       11
# 15        9
# 33        9
# 35        8
# 37        6
# 17        6
# 19        6
# 39        4
# 41        3
# 21        3
# 43        2
# 45        2
# 48        2
# 30        1
# 47        1
# 32        1
# 23        1
# 25        1
# 27        1
# 36        1
# 38        1
# 40        1
# 42        1
# 44        1
# 46        1
# 50        1
# Name: count, dtype: int64

# %%
translated_df = df

# %%
translated_df.wordtype.replace('ಹೆಸರುಪದ', 'noun', inplace=True)

# %%
translated_df.wordtype.replace('ಎಸಕಪದ', 'verb', inplace=True)

# %%
translated_df.wordtype.replace('ಪರಿಚೆಪದ', 'adjective', inplace=True)

# %%
translated_df.wordtype.replace('ಅವ್ಯಯ', 'adverb', inplace=True)

# %%
translated_df.wordtype.value_counts()
# Out:
# wordtype
# noun         27063
# verb          6246
# adjective     2330
# adverb         210
# Name: count, dtype: int64

# %%
unique_words = df.drop_duplicates(subset=['word', 'wordtype'])
unique_words.wordtype.value_counts()
# Out:
# wordtype
# noun         8080
# verb         1453
# adjective     874
# adverb         71
# Name: count, dtype: int64
