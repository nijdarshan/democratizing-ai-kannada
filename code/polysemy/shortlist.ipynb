# %%
import pandas as pd

# %%
df = pd.read_csv('translated.csv')
unique = df['word'].unique()

# %%
unique_df = pd.DataFrame(unique, columns=['word'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 unique.head
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'
